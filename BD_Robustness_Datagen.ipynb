# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib
from scipy import signal

# %pylab
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (16,12)
matplotlib.rcParams.update({'font.size': 22})

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx], idx
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
#signal gen - temp for now
Ti = 1
Te = 1.5
Tee = 0.5
t_neg = np.linspace(0, Ti, 800)
t_pos = np.linspace(0, Te, 800)
t = np.linspace(0,(Ti+Te),1600)
breath_neg = -1*signal.sawtooth(2 * np.pi * (1/Ti) * t_neg,0.2) - 1

figure()
plt.plot(breath_neg)
breath_pos = 0.7* (signal.sawtooth(2 * np.pi * (1/Te) * t_pos,0.3) + 1) 
breath = np.append(breath_neg, breath_pos)
figure()
plt.plot(breath)

breath_db = pd.DataFrame()

# %%
#stuff gen
length = 0.1
t_cough = np.linspace(0, length, int(length*800), endpoint=False)
plt.plot(signal.square(2 * np.pi * 1/length * t_cough,1))
